# %%
from duckdb_assistant import DuckDBAssistant

# %%
dda = DuckDBAssistant()

# %%
prompt = "I want to create a 3-month moving average of Amt_sales in my table Sales by Month"

# %%
dda.generate(prompt)
# Out:
# <module 'google.genai.errors' from '/Users/ss/duckdb-assistant/build/venv/lib/python3.14/site-packages/google/genai/errors.py'>
# Error with model gemini-3.7-flash: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# Retrying with next model after 2.38 seconds...
# {'query': 'SELECT\n    Month,\n    Amt_sales,\n    AVG(Amt_sales) OVER (\n        ORDER BY Month\n        ROWS BETWEEN 2 PRECEDING AND CURRENT ROW\n    ) AS moving_avg_3_month\nFROM Sales;',
#  'response_text': '```sql\nSELECT\n    Month,\n    Amt_sales,\n    AVG(Amt_sales) OVER (\n        ORDER BY Month\n        ROWS BETWEEN 2 PRECEDING AND CURRENT ROW\n    ) AS moving_avg_3_month\nFROM Sales;\n```'}

# %%
dda.generate(prompt, display_results=True)
# Out:
# <module 'google.genai.errors' from '/Users/ss/duckdb-assistant/build/venv/lib/python3.14/site-packages/google/genai/errors.py'>
# Error with model gemini-3.7-flash: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# Retrying with next model after 2.41 seconds...
# ```sql
# SELECT
#     *,
#     AVG(Amt_sales) OVER (
#         ORDER BY Month
#         ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
#     ) AS moving_avg_3_months
# FROM Sales;
# ```
# {'query': 'SELECT\n    *,\n    AVG(Amt_sales) OVER (\n        ORDER BY Month\n        ROWS BETWEEN 2 PRECEDING AND CURRENT ROW\n    ) AS moving_avg_3_months\nFROM Sales;',
#  'response_text': '```sql\nSELECT\n    *,\n    AVG(Amt_sales) OVER (\n        ORDER BY Month\n        ROWS BETWEEN 2 PRECEDING AND CURRENT ROW\n    ) AS moving_avg_3_months\nFROM Sales;\n```'}

# %%
resp = dda.generate(prompt, explain_results=True, display_results=True)
# Out:
# <module 'google.genai.errors' from '/Users/ss/duckdb-assistant/build/venv/lib/python3.14/site-packages/google/genai/errors.py'>
# Error with model gemini-3.7-flash: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# Retrying with next model after 2.17 seconds...
# ```sql
# SELECT
#     Month,
#     Amt_sales,
#     AVG(Amt_sales) OVER (
#         ORDER BY Month
#         ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
#     ) AS sales_3m_moving_avg
# FROM Sales;
# ```
#
# ### Explanation
#
# - **`AVG(Amt_sales) OVER (...)`**: Calculates the moving average of sales across the window frame defined in the clause.
# - **`ORDER BY Month`**: Ensures the window processes rows chronologically by date/month.
# ...

# %%
resp = dda.generate(prompt, explain_results=True)
# Out:
# <module 'google.genai.errors' from '/Users/ss/duckdb-assistant/build/venv/lib/python3.14/site-packages/google/genai/errors.py'>
# Error with model gemini-3.7-flash: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# Retrying with next model after 1.19 seconds...
# ```sql
# SELECT
#     Month,
#     Amt_sales,
#     AVG(Amt_sales) OVER (
#         ORDER BY Month
#         ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
#     ) AS sales_3_month_moving_avg
# FROM Sales;
# ```
#
# ### Explanation
#
# * **Window Function (`AVG() OVER ...`)**: Computes the mean of `Amt_sales` across a sliding window of rows.
# * **`ORDER BY Month`**: Ensures the dataset is processed in chronological order by month.
# ...
