# %%
from duckdb_assistant import DuckDBAssistant
import os

# %%
dda = DuckDBAssistant()

# %%
resp = dda.execute(sql_file_path=os.path.join(os.getcwd(),"..","generate","example_generate_sql_path.sql"))

# %%
dda.dd.execute("SELECT * FROM GREETING;").fetchall()
# Out:
# [('HEllo World',)]

# %%
prompt = "CREATE TABLE GREETING_EXEC_FILE AS SELECT 'HEllo World, with a file' as greeting;"
dda.execute(prompt, sql_file_path = os.path.join(os.getcwd(),"example_execute_file.sql"))
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
dda.dd.execute("SELECT * FROM GREETING_EXEC_FILE;").fetchall()
# Out:
# [('HEllo World, with a file',)]
